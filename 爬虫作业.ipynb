# %%
import requests
from bs4 import BeautifulSoup
def get_records():
    #设置请求Headers头部，根据自己的浏览器修改User-Agent
    header = {
        "User-Agent" : "Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.25 Safari/537.36 Core/1.70.3706.400 SLBrowser/10.0.3974.400",
        'Host': 'gamesafe.qq.com'
    }
    #创建爬取的记录列表
    record_list = []
    #爬取最近几天由于违规被封禁的LOL账号和所封禁的大区和昵称。
    for i in range(0, 10):
        #这10十个网页是由于不同的原因和在不同的时间被封禁账号展示
        url = 'https://gamesafe.qq.com/article/'+str(710+i)+'.shtml'
        r = requests.get(url, headers=header)
        #防止出现乱码而设置的编码格式
        r.encoding = 'utf-8'
        soup = BeautifulSoup(r.text, "lxml")
        #所有的数据都在<td>标签下
        td_list = soup.find_all('td')
        for each in td_list:
            #把每个数据存到record列表里
            record = each.text
            record_list.append(record)
    #打印出列表长度,每条记录有三条数据，
    print(len(record_list))
    return record_list

record1 = get_records()
print(record1)
# Out:
# 9660
# ...

# %%
import requests
from bs4 import BeautifulSoup
def get_records():
    #设置请求Headers头部，根据自己的浏览器修改User-Agent
    header = {
        "User-Agent" : "Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.25 Safari/537.36 Core/1.70.3706.400 SLBrowser/10.0.3974.400",
        'Host': 'gamesafe.qq.com'
    }
    #创建爬取的记录列表
    record_list = []
    #爬取最近几天由于违规被封禁的LOL账号和所封禁的大区和昵称。
    
    #这个网页是由于不同的原因和在不同的时间被封禁账号展示
    url = 'https://gamesafe.qq.com/article/'+str(710)+'.shtml'
    r = requests.get(url, headers=header)
    #防止出现乱码而设置的编码格式
    r.encoding = 'utf-8'
    soup = BeautifulSoup(r.text, "lxml")
    #所有的数据都在<td>标签下
    td_list = soup.find_all('td')
    for each in td_list:
        #把每个数据存到record列表里
        record = each.text
        record_list.append(record)
    #打印出列表长度,每条记录有三条数据，
    print(len(record_list))
    return record_list

record1 = get_records()
print(record1)
# Out:
# 1204
# ...

# %%
qq_id = record1[4::4]
qq_nick = record1[5::4]
print(qq_nick)
game_server = record1[6::4]
print(qq_id)
interval = record1[7::4]
print(interval)
game_server
# Out:
# ['leehoo', '梦回丶江南', 'ㅤㅤ骚ㅤㅤ', 'Doubleloving', '拥有蝗虫', '龙之缥缈', '耀眼的水滴', 'Angel猫仔', '咔妮油水', '我会变胖', '9运财富', '成都人民富起来', '每日更健康', '陌路淡然丶忆难忘', 'LOLsummer', '共精团大队长', '那一抹淡蓝丶', '诸天神佛丶', '东海5', '沐沐小', '杜蕾丝De草莓味', '波哥也潇洒', '丨江南STLYE', '物你去病症', '印度加能炮', '卧龙网吧一VIP6号', '艾莉丝贝萨流士', 'Saint丶Cyf', '冰冷若', '爱小河马', 'God丶Summy', '林慢慢慢慢', 'Rioღ', '0莫欺少年木有妻', '尼古拉斯比特币', '么益德蒙铎', '不准怂就是干', '心碎丶缠绵', '撸个宝宝的三月三', '酷优特', '只玩辅助不好混', '你秀的过我吗', '馨是馨怡的馨丶', 'TI9STO', '壹号头目', '回干就湿', '不错的觉悟', '熊猫TV丶白沙哥', 'LUCK耀扬', 'G你猜我猜不猜G', '七小甫', '123456s2003', '找个机友', 'comewww', '凯恩布莱斯', 'my刘续', '妖言得很', '孤独灬死亡', 'Passion丶剑痴', 'sexual', '老爷不老', '不要小ks我', 'PetltMonstre', '强大帅', '樱桃酸不酸', '妹子0大叔来了', '老牛拉货车', '玖壹壹911', '丶QiYueA', '坑无忌', '龙古辰', '成功男秀牛皮包袋', '项羽Dawn', 'math丶v', 'l丶ucas', 'yangskyone', '让我来绝杀你们', '神v兽v擦v尼v玛', '阿政传奇', '伟哥的意志', '人见人爱我搞你', '茫然9527', 'ᅟ皮ᅟ', 'tmcbs', '米青I示申', '魅影杀戮', 'zhang123adadadad', '撒撒人跳跳舞', '四月裂帛', '快喊声666', '狐狸河的狼嚎', '雄安菜鸟', '血色烟雾', '丿刚刚好', 'Angel晶晶', '小灬超越', 'Allen丶L', '吴先生', '帅丿哥哥来耍英雄', '传说配置', '老年打野'
# ...
